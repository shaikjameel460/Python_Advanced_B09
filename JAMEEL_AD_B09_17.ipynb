# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
df=pd.read_csv('countries (2).csv')

df
# Out:
#           country  year  population
# 0     Afghanistan  1952     8425333
# 1     Afghanistan  1957     9240934
# 2     Afghanistan  1962    10267083
# 3     Afghanistan  1967    11537966
# 4     Afghanistan  1972    13079460
# ...           ...   ...         ...
# 1699     Zimbabwe  1987     9216418
# 1700     Zimbabwe  1992    10704340
# 1701     Zimbabwe  1997    11404948
# 1702     Zimbabwe  2002    11926563
# 1703     Zimbabwe  2007    12311143
#
# [1704 rows x 3 columns]

# %%
afghanistan = df[df.country == 'Afghanistan']

afghanistan
# Out:
#         country  year  population
# 0   Afghanistan  1952     8425333
# 1   Afghanistan  1957     9240934
# 2   Afghanistan  1962    10267083
# 3   Afghanistan  1967    11537966
# 4   Afghanistan  1972    13079460
# 5   Afghanistan  1977    14880372
# 6   Afghanistan  1982    12881816
# 7   Afghanistan  1987    13867957
# 8   Afghanistan  1992    16317921
# 9   Afghanistan  1997    22227415
# 10  Afghanistan  2002    25268405
# 11  Afghanistan  2007    31889923

# %%
df.country == 'Afghanistan'
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1699    False
# 1700    False
# 1701    False
# 1702    False
# 1703    False
# Name: country, Length: 1704, dtype: bool

# %%
zimbabwe = df[df.country == 'Zimbabwe']

zimbabwe
# Out:
#        country  year  population
# 1692  Zimbabwe  1952     3080907
# 1693  Zimbabwe  1957     3646340
# 1694  Zimbabwe  1962     4277736
# 1695  Zimbabwe  1967     4995432
# 1696  Zimbabwe  1972     5861135
# 1697  Zimbabwe  1977     6642107
# 1698  Zimbabwe  1982     7636524
# 1699  Zimbabwe  1987     9216418
# 1700  Zimbabwe  1992    10704340
# 1701  Zimbabwe  1997    11404948
# 1702  Zimbabwe  2002    11926563
# 1703  Zimbabwe  2007    12311143

# %%
plt.plot(afghanistan.year,afghanistan.population)

plt.show()

# %%
plt.plot(zimbabwe.year,zimbabwe.population)

plt.show()

# %%
#Activity 1

# %%
df.head(1500)
# Out:
#           country  year  population
# 0     Afghanistan  1952     8425333
# 1     Afghanistan  1957     9240934
# 2     Afghanistan  1962    10267083
# 3     Afghanistan  1967    11537966
# 4     Afghanistan  1972    13079460
# ...           ...   ...         ...
# 1495        Syria  1987    11242847
# 1496        Syria  1992    13219062
# 1497        Syria  1997    15081016
# 1498        Syria  2002    17155814
# 1499        Syria  2007    19314747
#
# [1500 rows x 3 columns]

# %%
syria=df[df.country =='Syria']

syria
# Out:
#      country  year  population
# 1488   Syria  1952     3661549
# 1489   Syria  1957     4149908
# 1490   Syria  1962     4834621
# 1491   Syria  1967     5680812
# 1492   Syria  1972     6701172
# 1493   Syria  1977     7932503
# 1494   Syria  1982     9410494
# 1495   Syria  1987    11242847
# 1496   Syria  1992    13219062
# 1497   Syria  1997    15081016
# 1498   Syria  2002    17155814
# 1499   Syria  2007    19314747

# %%
df.head(900)
# Out:
#          country  year  population
# 0    Afghanistan  1952     8425333
# 1    Afghanistan  1957     9240934
# 2    Afghanistan  1962    10267083
# 3    Afghanistan  1967    11537966
# 4    Afghanistan  1972    13079460
# ..           ...   ...         ...
# 895      Liberia  1987     2269414
# 896      Liberia  1992     1912974
# 897      Liberia  1997     2200725
# 898      Liberia  2002     2814651
# 899      Liberia  2007     3193942
#
# [900 rows x 3 columns]

# %%
liberia=df[df.country =='Liberia']

liberia
# Out:
#      country  year  population
# 888  Liberia  1952      863308
# 889  Liberia  1957      975950
# 890  Liberia  1962     1112796
# 891  Liberia  1967     1279406
# 892  Liberia  1972     1482628
# 893  Liberia  1977     1703617
# 894  Liberia  1982     1956875
# 895  Liberia  1987     2269414
# 896  Liberia  1992     1912974
# 897  Liberia  1997     2200725
# 898  Liberia  2002     2814651
# 899  Liberia  2007     3193942

# %%
plt.plot(syria.year,syria.population)

plt.show()

# %%
plt.plot(liberia.year,liberia.population)

plt.show()

# %%
#activity 2

# %%
df.tail(700)
# Out:
#          country  year  population
# 1004    Mongolia  1992     2312802
# 1005    Mongolia  1997     2494803
# 1006    Mongolia  2002     2674234
# 1007    Mongolia  2007     2874127
# 1008  Montenegro  1952      413834
# ...          ...   ...         ...
# 1699    Zimbabwe  1987     9216418
# 1700    Zimbabwe  1992    10704340
# 1701    Zimbabwe  1997    11404948
# 1702    Zimbabwe  2002    11926563
# 1703    Zimbabwe  2007    12311143
#
# [700 rows x 3 columns]

# %%
mongolia=df[df.country =='Mongolia']

mongolia
# Out:
#        country  year  population
# 996   Mongolia  1952      800663
# 997   Mongolia  1957      882134
# 998   Mongolia  1962     1010280
# 999   Mongolia  1967     1149500
# 1000  Mongolia  1972     1320500
# 1001  Mongolia  1977     1528000
# 1002  Mongolia  1982     1756032
# 1003  Mongolia  1987     2015133
# 1004  Mongolia  1992     2312802
# 1005  Mongolia  1997     2494803
# 1006  Mongolia  2002     2674234
# 1007  Mongolia  2007     2874127

# %%
df.tail(1200)
# Out:
#        country  year  population
# 504   Ethiopia  1952    20860941
# 505   Ethiopia  1957    22815614
# 506   Ethiopia  1962    25145372
# 507   Ethiopia  1967    27860297
# 508   Ethiopia  1972    30770372
# ...        ...   ...         ...
# 1699  Zimbabwe  1987     9216418
# 1700  Zimbabwe  1992    10704340
# 1701  Zimbabwe  1997    11404948
# 1702  Zimbabwe  2002    11926563
# 1703  Zimbabwe  2007    12311143
#
# [1200 rows x 3 columns]

# %%
ethiopia=df[df.country =='Ethiopia']

ethiopia
# Out:
#       country  year  population
# 504  Ethiopia  1952    20860941
# 505  Ethiopia  1957    22815614
# 506  Ethiopia  1962    25145372
# 507  Ethiopia  1967    27860297
# 508  Ethiopia  1972    30770372
# 509  Ethiopia  1977    34617799
# 510  Ethiopia  1982    38111756
# 511  Ethiopia  1987    42999530
# 512  Ethiopia  1992    52088559
# 513  Ethiopia  1997    59861301
# 514  Ethiopia  2002    67946797
# 515  Ethiopia  2007    76511887

# %%
plt.plot(mongolia.year,mongolia.population)

plt.show()

# %%
plt.plot(ethiopia.year,ethiopia.population)

plt.show()

# %%
#Activity 3

# %%
df=pd.read_csv('countries (2).csv',nrows=100)

df
# Out:
#         country  year  population
# 0   Afghanistan  1952     8425333
# 1   Afghanistan  1957     9240934
# 2   Afghanistan  1962    10267083
# 3   Afghanistan  1967    11537966
# 4   Afghanistan  1972    13079460
# ..          ...   ...         ...
# 95      Bahrain  2007      708573
# 96   Bangladesh  1952    46886859
# 97   Bangladesh  1957    51365468
# 98   Bangladesh  1962    56839289
# 99   Bangladesh  1967    62821884
#
# [100 rows x 3 columns]

# %%
bahrain=df[df.country =='Bahrain']

bahrain
# Out:
#     country  year  population
# 84  Bahrain  1952      120447
# 85  Bahrain  1957      138655
# 86  Bahrain  1962      171863
# 87  Bahrain  1967      202182
# 88  Bahrain  1972      230800
# 89  Bahrain  1977      297410
# 90  Bahrain  1982      377967
# 91  Bahrain  1987      454612
# 92  Bahrain  1992      529491
# 93  Bahrain  1997      598561
# 94  Bahrain  2002      656397
# 95  Bahrain  2007      708573

# %%
bangladesh=df[df.country =='Bangladesh']

bangladesh
# Out:
#        country  year  population
# 96  Bangladesh  1952    46886859
# 97  Bangladesh  1957    51365468
# 98  Bangladesh  1962    56839289
# 99  Bangladesh  1967    62821884

# %%
plt.plot(bahrain.year,bahrain.population)

plt.show()

# %%
plt.plot(bangladesh.year,bangladesh.population)

plt.show()

# %%
#Activity 4

# %%
df=pd.read_csv('countries (2).csv',nrows=76)
df
# Out:
#         country  year  population
# 0   Afghanistan  1952     8425333
# 1   Afghanistan  1957     9240934
# 2   Afghanistan  1962    10267083
# 3   Afghanistan  1967    11537966
# 4   Afghanistan  1972    13079460
# ..          ...   ...         ...
# 71    Australia  2007    20434176
# 72      Austria  1952     6927772
# 73      Austria  1957     6965860
# 74      Austria  1962     7129864
# 75      Austria  1967     7376998
#
# [76 rows x 3 columns]

# %%
australia=df[df.country =='Australia']

australia
# Out:
#       country  year  population
# 60  Australia  1952     8691212
# 61  Australia  1957     9712569
# 62  Australia  1962    10794968
# 63  Australia  1967    11872264
# 64  Australia  1972    13177000
# 65  Australia  1977    14074100
# 66  Australia  1982    15184200
# 67  Australia  1987    16257249
# 68  Australia  1992    17481977
# 69  Australia  1997    18565243
# 70  Australia  2002    19546792
# 71  Australia  2007    20434176

# %%
austria=df[df.country =='Austria']

austria
# Out:
#     country  year  population
# 72  Austria  1952     6927772
# 73  Austria  1957     6965860
# 74  Austria  1962     7129864
# 75  Austria  1967     7376998

# %%
plt.plot(australia.year,australia.population)

plt.show()

# %%
plt.plot(austria.year,austria.population)

plt.show()
